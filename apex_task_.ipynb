# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavishya-2005/apex-planet-data-analytics--task-2/blob/main/apex_task_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a871b452-7310-4288-9607-aabe60d0e7e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a871b452-7310-4288-9607-aabe60d0e7e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("ApexPlanet_DataAnalytics_Dataset.csv")

# %%
df.head()
# Out:
#     Order_ID  Order_Date Customer_ID Customer_Name   Age  Gender       City  \
# 0  ORD100002  2025-02-25    CUST5529  Customer_227  30.0  Female  Bengaluru
# 1  ORD100003  2025-10-14    CUST3127  Customer_182  63.0    Male  Bengaluru
# 2  ORD100004  2025-05-13    CUST8887  Customer_487  62.0  Female  Bengaluru
# 3  ORD100005  2025-12-02    CUST2515  Customer_470  65.0  Female    Kolkata
# 4  ORD100006  2025-11-20    CUST4796  Customer_380  44.0    Male  Bengaluru
#
#   Product     Category  Quantity  Unit_Price  Total_Sales
# 0    Rice      Grocery         7     2829.77     19808.39
# 1    Book    Education         5    27906.16    139530.80
# 2    Book    Education         8    37491.06    299928.48
# 3  Mobile  Electronics         9    28541.36    256872.24
# 4    Rice      Grocery        10    14036.59    140365.90

# %%
df.tail()
# Out:
#       Order_ID  Order_Date Customer_ID Customer_Name   Age  Gender       City  \
# 995  ORD100997  2025-11-07    CUST6410  Customer_301  61.0    Male       Gaya
# 996  ORD100998  2025-09-03    CUST7618  Customer_154  25.0    Male       Gaya
# 997  ORD100999  2025-09-30    CUST9544  Customer_140  62.0  Female  Hyderabad
# 998  ORD101000  2025-02-21    CUST9501  Customer_241   NaN    Male      Delhi
# 999  ORD101001  2025-04-23    CUST2714   Customer_98  58.0  Female       Gaya
#
#     Product     Category  Quantity  Unit_Price  Total_Sales
# 995  Laptop  Electronics         9    35405.54    318649.86
# 996   Shoes      Fashion         5    18454.65     92273.25
# 997  Laptop  Electronics         9    12971.59    116744.31
# 998  Mobile  Electronics         9     2879.01     25911.09
# 999   Chair    Furniture         9    22493.87    202444.83

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Customer_Name', 'Age',
#        'Gender', 'City', 'Product', 'Category', 'Quantity', 'Unit_Price',
#        'Total_Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order_ID          object
# Order_Date        object
# Customer_ID       object
# Customer_Name     object
# Age              float64
# Gender            object
# City              object
# Product           object
# Category          object
# Quantity           int64
# Unit_Price       float64
# Total_Sales      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Customer_Name     0
# Age              20
# Gender            0
# City             13
# Product           0
# Category          0
# Quantity          0
# Unit_Price        0
# Total_Sales       0
# dtype: int64

# %%
(df.isnull().sum() / len(df) * 100).round(2)
# Out:
# Order_ID         0.0
# Order_Date       0.0
# Customer_ID      0.0
# Customer_Name    0.0
# Age              2.0
# Gender           0.0
# City             1.3
# Product          0.0
# Category         0.0
# Quantity         0.0
# Unit_Price       0.0
# Total_Sales      0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       1000 non-null   object
#  1   Order_Date     1000 non-null   object
#  2   Customer_ID    1000 non-null   object
#  3   Customer_Name  1000 non-null   object
#  4   Age            980 non-null    float64
#  5   Gender         1000 non-null   object
#  6   City           987 non-null    object
#  7   Product        1000 non-null   object
#  8   Category       1000 non-null   object
#  9   Quantity       1000 non-null   int64
#  10  Unit_Price     1000 non-null   float64
#  11  Total_Sales    1000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 93.9+ KB

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Bengaluru', 'Kolkata', 'Hyderabad', 'Patna', 'Mumbai', 'Delhi',
#        'Gaya', 'Pune', nan], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Grocery', 'Education', 'Electronics', 'Fashion', 'Furniture'],
#       dtype=object)

# %%
df['Product'].unique()
# Out:
# array(['Rice', 'Book', 'Mobile', 'Laptop', 'Shoes', 'Chair'], dtype=object)

# %%
for col in df.select_dtypes(include='object'):
      print("\n", col)
      print(df[col].dropna().unique()[:20])
# Out:
#  Order_ID
# ['ORD100002' 'ORD100003' 'ORD100004' 'ORD100005' 'ORD100006' 'ORD100007'
#  'ORD100008' 'ORD100009' 'ORD100010' 'ORD100011' 'ORD100012' 'ORD100013'
#  'ORD100014' 'ORD100015' 'ORD100016' 'ORD100017' 'ORD100018' 'ORD100019'
#  'ORD100020' 'ORD100021']
#
#  Order_Date
# ['2025-02-25' '2025-10-14' '2025-05-13' '2025-12-02' '2025-11-20'
#  '2025-12-31' '2025-12-05' '2025-11-21' '2025-04-16' '2025-05-05'
#  '2025-05-02' '2025-05-06' '2025-04-24' '2025-03-12' '2025-08-30'
#  '2025-11-30' '2025-10-19' '2025-07-24' '2025-03-20' '2025-03-18']
#
#  Customer_ID
# ['CUST5529' 'CUST3127' 'CUST8887' 'CUST2515' 'CUST4796' 'CUST3952'
#  'CUST1758' 'CUST9622' 'CUST9770' 'CUST1312' 'CUST9642' 'CUST3228'
#  'CUST1038' 'CUST6413' 'CUST8660' 'CUST9307' 'CUST4363' 'CUST3508'
#  'CUST5806' 'CUST6504']
#
#  Customer_Name
# ['Customer_227' 'Customer_182' 'Customer_487' 'Customer_470'
#  'Customer_380' 'Customer_71' 'Customer_335' 'Customer_224' 'Customer_494'
# ...

# %%
df.describe()
# Out:
#               Age     Quantity    Unit_Price    Total_Sales
# count  980.000000  1000.000000   1000.000000    1000.000000
# mean    41.360204     5.435000  25486.783410  139399.439650
# std     13.822597     2.838632  14179.402361  114100.051546
# min     18.000000     1.000000    145.780000     437.340000
# 25%     30.000000     3.000000  13895.722500   47066.632500
# 50%     41.000000     5.000000  25398.740000  108594.025000
# 75%     54.000000     8.000000  37512.382500  203722.882500
# max     65.000000    10.000000  49997.530000  493677.500000

# %%
import matplotlib.pyplot as plt

df.boxplot(column='Age')
plt.show()

# %%
df.boxplot(column='Quantity')
plt.show()

# %%
df.boxplot(column='Unit_Price')
plt.show()

# %%
df.boxplot(column='Total_Sales')
plt.show()

# %%
df['Age'].describe()
# Out:
# count    980.000000
# mean      41.360204
# std       13.822597
# min       18.000000
# 25%       30.000000
# 50%       41.000000
# 75%       54.000000
# max       65.000000
# Name: Age, dtype: float64

# %%
df[(df['Age'] < 0) | (df['Age'] > 100)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df[df['Quantity'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df[df['Unit_Price'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df[df['Total_Sales'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Customer_Name     0
# Age              20
# Gender            0
# City             13
# Product           0
# Category          0
# Quantity          0
# Unit_Price        0
# Total_Sales       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       1000 non-null   object
#  1   Order_Date     1000 non-null   object
#  2   Customer_ID    1000 non-null   object
#  3   Customer_Name  1000 non-null   object
#  4   Age            980 non-null    float64
#  5   Gender         1000 non-null   object
#  6   City           987 non-null    object
#  7   Product        1000 non-null   object
#  8   Category       1000 non-null   object
#  9   Quantity       1000 non-null   int64
#  10  Unit_Price     1000 non-null   float64
#  11  Total_Sales    1000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 93.9+ KB

# %%
df['Order_Date'].head(10)
# Out:
# 0    2025-02-25
# 1    2025-10-14
# 2    2025-05-13
# 3    2025-12-02
# 4    2025-11-20
# 5    2025-12-31
# 6    2025-10-14
# 7    2025-12-05
# 8    2025-11-21
# 9    2025-04-16
# Name: Order_Date, dtype: object

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Bengaluru', 'Kolkata', 'Hyderabad', 'Patna', 'Mumbai', 'Delhi',
#        'Gaya', 'Pune', nan], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Grocery', 'Education', 'Electronics', 'Fashion', 'Furniture'],
#       dtype=object)

# %%
df['Product'].unique()
# Out:
# array(['Rice', 'Book', 'Mobile', 'Laptop', 'Shoes', 'Chair'], dtype=object)

# %%
for col in df.select_dtypes(include='object'):
      print("\n---", col, "---")
      print(df[col].unique())
# Out:
# --- Order_ID ---
# ['ORD100002' 'ORD100003' 'ORD100004' 'ORD100005' 'ORD100006' 'ORD100007'
#  'ORD100008' 'ORD100009' 'ORD100010' 'ORD100011' 'ORD100012' 'ORD100013'
#  'ORD100014' 'ORD100015' 'ORD100016' 'ORD100017' 'ORD100018' 'ORD100019'
#  'ORD100020' 'ORD100021' 'ORD100022' 'ORD100023' 'ORD100024' 'ORD100025'
#  'ORD100026' 'ORD100027' 'ORD100028' 'ORD100029' 'ORD100030' 'ORD100031'
#  'ORD100032' 'ORD100033' 'ORD100034' 'ORD100035' 'ORD100036' 'ORD100037'
#  'ORD100038' 'ORD100039' 'ORD100040' 'ORD100041' 'ORD100042' 'ORD100043'
#  'ORD100044' 'ORD100045' 'ORD100046' 'ORD100047' 'ORD100048' 'ORD100049'
#  'ORD100050' 'ORD100051' 'ORD100052' 'ORD100053' 'ORD100054' 'ORD100055'
#  'ORD100056' 'ORD100057' 'ORD100058' 'ORD100059' 'ORD100060' 'ORD100061'
#  'ORD100062' 'ORD100063' 'ORD100064' 'ORD100065' 'ORD100066' 'ORD100067'
#  'ORD100068' 'ORD100069' 'ORD100070' 'ORD100071' 'ORD100072' 'ORD100073'
#  'ORD100074' 'ORD100075' 'ORD100076' 'ORD100077' 'ORD100078' 'ORD100079'
# ...

# %%
df[['Age', 'Quantity', 'Unit_Price', 'Total_Sales']].describe()
# Out:
#               Age     Quantity    Unit_Price    Total_Sales
# count  980.000000  1000.000000   1000.000000    1000.000000
# mean    41.360204     5.435000  25486.783410  139399.439650
# std     13.822597     2.838632  14179.402361  114100.051546
# min     18.000000     1.000000    145.780000     437.340000
# 25%     30.000000     3.000000  13895.722500   47066.632500
# 50%     41.000000     5.000000  25398.740000  108594.025000
# 75%     54.000000     8.000000  37512.382500  203722.882500
# max     65.000000    10.000000  49997.530000  493677.500000

# %%
import matplotlib.pyplot as plt

df.boxplot(column='Age')
plt.title('Age Outliers')
plt.show()

# %%
df.boxplot(column='Quantity')
plt.title('Quantity Outliers')
plt.show()

# %%
df.boxplot(column='Unit_Price')
plt.title('Unit Price Outliers')
plt.show()

# %%
df.boxplot(column='Total_Sales')
plt.title('Total Sales Outliers')
plt.show()

# %%
df[(df['Age'] < 0) | (df['Age'] > 100)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df[df['Quantity'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df[df['Unit_Price'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df[df['Total_Sales'] <= 0]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales]
# Index: []

# %%
df['Calculated_Sales'] = df['Quantity'] * df['Unit_Price']

df[df['Total_Sales'].round(2) != df['Calculated_Sales'].round(2)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Customer_Name, Age, Gender, City, Product, Category, Quantity, Unit_Price, Total_Sales, Calculated_Sales]
# Index: []

# %%
df.head()
# Out:
#     Order_ID  Order_Date Customer_ID Customer_Name   Age  Gender       City  \
# 0  ORD100002  2025-02-25    CUST5529  Customer_227  30.0  Female  Bengaluru
# 1  ORD100003  2025-10-14    CUST3127  Customer_182  63.0    Male  Bengaluru
# 2  ORD100004  2025-05-13    CUST8887  Customer_487  62.0  Female  Bengaluru
# 3  ORD100005  2025-12-02    CUST2515  Customer_470  65.0  Female    Kolkata
# 4  ORD100006  2025-11-20    CUST4796  Customer_380  44.0    Male  Bengaluru
#
#   Product     Category  Quantity  Unit_Price  Total_Sales  Calculated_Sales
# 0    Rice      Grocery         7     2829.77     19808.39          19808.39
# 1    Book    Education         5    27906.16    139530.80         139530.80
# 2    Book    Education         8    37491.06    299928.48         299928.48
# 3  Mobile  Electronics         9    28541.36    256872.24         256872.24
# 4    Rice      Grocery        10    14036.59    140365.90         140365.90

# %%
df.isnull().sum()
# Out:
# Order_ID             0
# Order_Date           0
# Customer_ID          0
# Customer_Name        0
# Age                 20
# Gender               0
# City                13
# Product              0
# Category             0
# Quantity             0
# Unit_Price           0
# Total_Sales          0
# Calculated_Sales     0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['City'] = df['City'].fillna(df['City'].mode()[0])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order_Date'] = pd.to_datetime(
      df['Order_Date'],
          errors='coerce'

)

# %%
df['Order_Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
text_columns = df.select_dtypes(include='object').columns

for col in text_columns:
    df[col] = df[col].str.strip()

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['Gender'] = df['Gender'].str.strip().str.title()

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Bengaluru', 'Kolkata', 'Hyderabad', 'Patna', 'Mumbai', 'Delhi',
#        'Gaya', 'Pune'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Grocery', 'Education', 'Electronics', 'Fashion', 'Furniture'],
#       dtype=object)

# %%
df['Product'].unique()
# Out:
# array(['Rice', 'Book', 'Mobile', 'Laptop', 'Shoes', 'Chair'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   object
#  1   Order_Date        1000 non-null   datetime64[ns]
#  2   Customer_ID       1000 non-null   object
#  3   Customer_Name     1000 non-null   object
#  4   Age               1000 non-null   float64
#  5   Gender            1000 non-null   object
#  6   City              1000 non-null   object
#  7   Product           1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Quantity          1000 non-null   int64
#  10  Unit_Price        1000 non-null   float64
#  11  Total_Sales       1000 non-null   float64
#  12  Calculated_Sales  1000 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 101.7+ KB

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Age                 0
# Gender              0
# City                0
# Product             0
# Category            0
# Quantity            0
# Unit_Price          0
# Total_Sales         0
# Calculated_Sales    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Age                 0
# Gender              0
# City                0
# Product             0
# Category            0
# Quantity            0
# Unit_Price          0
# Total_Sales         0
# Calculated_Sales    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   object
#  1   Order_Date        1000 non-null   datetime64[ns]
#  2   Customer_ID       1000 non-null   object
#  3   Customer_Name     1000 non-null   object
#  4   Age               1000 non-null   float64
#  5   Gender            1000 non-null   object
#  6   City              1000 non-null   object
#  7   Product           1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Quantity          1000 non-null   int64
#  10  Unit_Price        1000 non-null   float64
#  11  Total_Sales       1000 non-null   float64
#  12  Calculated_Sales  1000 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(7)
# memory usage: 101.7+ KB

# %%
df.head()
# Out:
#     Order_ID Order_Date Customer_ID Customer_Name   Age  Gender       City  \
# 0  ORD100002 2025-02-25    CUST5529  Customer_227  30.0  Female  Bengaluru
# 1  ORD100003 2025-10-14    CUST3127  Customer_182  63.0    Male  Bengaluru
# 2  ORD100004 2025-05-13    CUST8887  Customer_487  62.0  Female  Bengaluru
# 3  ORD100005 2025-12-02    CUST2515  Customer_470  65.0  Female    Kolkata
# 4  ORD100006 2025-11-20    CUST4796  Customer_380  44.0    Male  Bengaluru
#
#   Product     Category  Quantity  Unit_Price  Total_Sales  Calculated_Sales
# 0    Rice      Grocery         7     2829.77     19808.39          19808.39
# 1    Book    Education         5    27906.16    139530.80         139530.80
# 2    Book    Education         8    37491.06    299928.48         299928.48
# 3  Mobile  Electronics         9    28541.36    256872.24         256872.24
# 4    Rice      Grocery        10    14036.59    140365.90         140365.90

# %%
df['Order_Year'] = df['Order_Date'].dt.year

# %%
df[['Order_Date', 'Order_Year']].head()
# Out:
#   Order_Date  Order_Year
# 0 2025-02-25        2025
# 1 2025-10-14        2025
# 2 2025-05-13        2025
# 3 2025-12-02        2025
# 4 2025-11-20        2025

# %%
df['Order_Month'] = df['Order_Date'].dt.month

# %%
df[['Order_Date', 'Order_Month']].head()
# Out:
#   Order_Date  Order_Month
# 0 2025-02-25            2
# 1 2025-10-14           10
# 2 2025-05-13            5
# 3 2025-12-02           12
# 4 2025-11-20           11

# %%
df['Order_Month_Name'] = df['Order_Date'].dt.month_name()

# %%
df[['Order_Date', 'Order_Month_Name']].head()
# Out:
#   Order_Date Order_Month_Name
# 0 2025-02-25         February
# 1 2025-10-14          October
# 2 2025-05-13              May
# 3 2025-12-02         December
# 4 2025-11-20         November

# %%
df['Age_Group'] = pd.cut(
      df['Age'],
          bins=[0, 18, 30, 45, 60, 100],
              labels=['Under 18', '18-30', '31-45', '46-60', '60+']
              )

# %%
df[['Age', 'Age_Group']].head(10)
# Out:
#     Age Age_Group
# 0  30.0     18-30
# 1  63.0       60+
# 2  62.0       60+
# 3  65.0       60+
# 4  44.0     31-45
# 5  40.0     31-45
# 6  61.0       60+
# 7  35.0     31-45
# 8  41.0     31-45
# 9  30.0     18-30

# %%
df['Calculated_Sales'] = df['Quantity'] * df['Unit_Price']

# %%
df['Sales_Difference'] = (
      df['Total_Sales'] - df['Calculated_Sales']
      ).round(2)

# %%
df['Sales_Difference'].value_counts().head()
# Out:
# Sales_Difference
# 0.0    1000
# Name: count, dtype: int64

# %%
df.drop(
      columns=['Calculated_Sales', 'Sales_Difference'],
          inplace=True
          )

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Customer_ID         0
# Customer_Name       0
# Age                 0
# Gender              0
# City                0
# Product             0
# Category            0
# Quantity            0
# Unit_Price          0
# Total_Sales         0
# Order_Year          0
# Order_Month         0
# Order_Month_Name    0
# Age_Group           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1000 non-null   object
#  1   Order_Date        1000 non-null   datetime64[ns]
#  2   Customer_ID       1000 non-null   object
#  3   Customer_Name     1000 non-null   object
#  4   Age               1000 non-null   float64
#  5   Gender            1000 non-null   object
#  6   City              1000 non-null   object
#  7   Product           1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Quantity          1000 non-null   int64
#  10  Unit_Price        1000 non-null   float64
#  11  Total_Sales       1000 non-null   float64
#  12  Order_Year        1000 non-null   int32
#  13  Order_Month       1000 non-null   int32
#  14  Order_Month_Name  1000 non-null   object
#  15  Age_Group         1000 non-null   category
# ...

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Customer_ID', 'Customer_Name', 'Age',
#        'Gender', 'City', 'Product', 'Category', 'Quantity', 'Unit_Price',
#        'Total_Sales', 'Order_Year', 'Order_Month', 'Order_Month_Name',
#        'Age_Group'],
#       dtype='object')

# %%
df.head()
# Out:
#     Order_ID Order_Date Customer_ID Customer_Name   Age  Gender       City  \
# 0  ORD100002 2025-02-25    CUST5529  Customer_227  30.0  Female  Bengaluru
# 1  ORD100003 2025-10-14    CUST3127  Customer_182  63.0    Male  Bengaluru
# 2  ORD100004 2025-05-13    CUST8887  Customer_487  62.0  Female  Bengaluru
# 3  ORD100005 2025-12-02    CUST2515  Customer_470  65.0  Female    Kolkata
# 4  ORD100006 2025-11-20    CUST4796  Customer_380  44.0    Male  Bengaluru
#
#   Product     Category  Quantity  Unit_Price  Total_Sales  Order_Year  \
# 0    Rice      Grocery         7     2829.77     19808.39        2025
# 1    Book    Education         5    27906.16    139530.80        2025
# 2    Book    Education         8    37491.06    299928.48        2025
# 3  Mobile  Electronics         9    28541.36    256872.24        2025
# 4    Rice      Grocery        10    14036.59    140365.90        2025
#
#    Order_Month Order_Month_Name Age_Group
# 0            2         February     18-30
# ...

# %%
df.to_csv("cleaned_dataset.csv", index=False)

# %%
import os

os.path.exists("cleaned_dataset.csv")
# Out:
# False
